# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf


#티스토리 업로드시 최적화 코드
#from IPython.core.display import display, HTML
#display(HTML("<style>.container {width:90% !important;}</style>"))

# %% [markdown]
# # 2023.05.01
# # TRAINING
# Dataset Info.
#
# train.csv [파일]
#
#     ID : 샘플 고유 ID
#     User-ID : 유저 고유 ID
#     Book-ID : 도서 고유 ID
#     유저 정보
#     Age : 나이
#     Location : 지역
#     도서 정보
#     Book-Title : 도서 명
#     Book-Author : 도서 저자
#     Year-Of-Publication : 도서 출판 년도 (-1일 경우 결측 혹은 알 수 없음)
#     Publisher : 출판사
#     Book-Rating : 유저가 도서에 부여한 평점 (0점 ~ 10점)
#
#
# test.csv [파일]
#
#     ID : 샘플 고유 ID
#     User-ID : 유저 고유 ID
#     Book-ID : 도서 고유 ID
#     유저 정보
#     Age : 나이
#     Location : 지역
#     도서 정보
#     Book-Title : 도서 명
#     Book-Author : 도서 저자
#     Year-Of-Publication : 도서 출판 년도 (-1일 경우 결측 혹은 알 수 없음)
#     Publisher : 출판사
#
#
# sample_submission.csv [제출양식]
#
#     ID : 샘플 고유 ID
#     Book-Rating : 예측한 유저가 도서에 부여할 평점

# %%
import pandas as pd

# %%
import numpy as np
import random
import os
import gc

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) # Seed 고정

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv( 'test.csv')
sample_submission = pd.read_csv('sample_submission.csv', index_col = 0)

# %%
train['City'] = [(i.split(',')[0]).lstrip().title() for i in train['Location']]
train['State'] = [(i.split(',')[1]).lstrip().title() for i in train['Location']]
train['Country'] = [(i.split(',')[2]).lstrip().title() for i in train['Location']]

# %%
test['City'] = [(i.split(',')[0]).lstrip().title() for i in test['Location']]
test['State'] = [(i.split(',')[1]).lstrip().title() for i in test['Location']]
test['Country'] = [(i.split(',')[2]).lstrip().title() for i in test['Location']]

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.1.1

# %%
# 나이 그룹화
labels = ['0-3','3-6','6-8','8-12','12-18','18-25','25-34','35-44','45-54','55-64','65-74','75+']
bins = [0, 3, 6, 8, 12, 18, 25, 34, 44, 54, 64, 74, 250]
train['Age_gb'] = pd.cut(train.Age, bins, labels = labels,include_lowest = True)

# %%
test['Age_gb'] = pd.cut(test.Age, bins, labels = labels,include_lowest = True)

# %%
from sklearn.preprocessing import OrdinalEncoder

FEATURE = ['User-ID', 'Book-Title','Book-Author','Publisher', 'City','State','Country','Age_gb']#,'Topic_num']

train_lb = train.__deepcopy__() 
test_lb = test.__deepcopy__()

#train_lb = pd.merge(train_lb, title, on = 'Book-Title_st', how = 'left')
#test_lb = pd.merge(test_lb, title_t, on = 'Book-Title_st', how = 'left')

train_lb = train_lb.drop(columns = ['Book-ID', 'Location'])
test_lb = test_lb.drop(columns = ['Book-ID', 'Location'])

train_lb[FEATURE] = train_lb[FEATURE].astype(str) 
test_lb[FEATURE] = test_lb[FEATURE].astype(str)

for i in FEATURE:
    # train에는 없고, test에는 있는 원소는 -2 처리
    oe = OrdinalEncoder(handle_unknown='use_encoded_value',
                         unknown_value=-2)
    oe=oe.fit(train_lb[i].to_numpy().reshape(-1, 1))
    train_lb[i] = oe.transform(train_lb[i].to_numpy().reshape(-1, 1))
    test_lb[i] = oe.transform(test_lb[i].to_numpy().reshape(-1, 1))

# %%
X_train = train_lb.drop(columns = ['ID','Book-Rating'])#,'Book-Title_st','City_st','State_st','Country_st'])
y_train = train_lb['Book-Rating']
x_test = test_lb.drop(columns = ['ID'])#,'Book-Title_st','City_st','State_st','Country_st'])

# %%
from catboost import CatBoostRegressor 

model = CatBoostRegressor(random_seed = 113,
                          l2_leaf_reg = 0.003426034644149707,
                          max_bin = 358,
                          subsample = 0.9974697184313627,
                          learning_rate = 0.009464402227606937,
                          max_depth = 11,
                          min_data_in_leaf = 139,
                          eval_metric = 'RMSE',
                          iterations = 8694,
                          task_type='GPU',
                          bootstrap_type = 'Poisson',
                          early_stopping_rounds = 100,
                          verbose=500
                          )

# %%
from sklearn.model_selection import KFold, StratifiedKFold

k = 20 # a number of folds 
skfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=113)
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from sklearn.metrics import r2_score
from catboost import Pool

y_valid_pred = 0*y_train
y_test_pred = 0

FEATURE = ['User-ID', 'Book-Title','Book-Author','Publisher', 'City','State','Country','Age_gb']#, 'Topic_num']

for i, (train_index, test_index) in enumerate(skfold.split(X_train, y_train)):    
    X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[test_index]

    train_pool = Pool(data=X_train_fold.astype('int'), label=y_train_fold, cat_features=FEATURE)
    valid_pool = Pool(data=X_valid_fold.astype('int'), label=y_valid_fold, cat_features=FEATURE)

    print( "\nFold ", i)
    
    fit_model = model.fit(train_pool, 
                          eval_set=valid_pool,
                          use_best_model=True
                          )
    print( "  N trees = ", model.tree_count_ )
        
    # Generate validation predictions for this fold
    pred = fit_model.predict(X_valid_fold.astype('int'))
    y_valid_pred.iloc[test_index] = pred

    def score_model(model,X_train, X_test, y_train, y_test,
               show_plot=True):   
        y_pred = np.clip(model.predict(X_test.astype('int')),0,10)
        print(f"Test score: {r2_score(y_test, y_pred)}")
        print("MSE: ", mean_squared_error(y_test, y_pred))
        print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
    
        predictions_comparision = pd.DataFrame({'Actual': y_test.tolist(), 'Predicted': y_pred.tolist()}).sample(25)
        if show_plot == True:
            predictions_comparision.plot(kind="bar", figsize=(12,8),title="Actual vs predicted values")
            print(predictions_comparision.sample(10))    
    
    
        return {
            "test_score_r2" : r2_score(y_test, y_pred),
            "test_score_mse" : mean_squared_error(y_test, y_pred),
            "test_score_rmse" : np.sqrt(mean_squared_error(y_test, y_pred))
            }
    score_model(fit_model, X_train_fold, X_valid_fold, y_train_fold, y_valid_fold, show_plot=True)
    
    # Predict value Clipping
    y_test_pred +=  np.clip(fit_model.predict(x_test[X_valid_fold.columns].astype('int')),0.0,10.0)
    
y_test_pred /= k  # Average test set predictions
# Out:
# Fold  0
# 0:	learn: 3.8400301	test: 3.8396270	best: 3.8396270 (0)	total: 78.5ms	remaining: 11m 22s
# 500:	learn: 3.3160830	test: 3.2876170	best: 3.2876170 (500)	total: 54.2s	remaining: 14m 46s
# 1000:	learn: 3.2730733	test: 3.2685398	best: 3.2685398 (1000)	total: 2m 19s	remaining: 17m 54s
# 1500:	learn: 3.2429467	test: 3.2607756	best: 3.2607729 (1498)	total: 3m 7s	remaining: 14m 59s
# 2000:	learn: 3.2173120	test: 3.2566708	best: 3.2566708 (2000)	total: 3m 54s	remaining: 13m 4s
# 2500:	learn: 3.1934941	test: 3.2535543	best: 3.2535543 (2500)	total: 4m 41s	remaining: 11m 36s
# 3000:	learn: 3.1707710	test: 3.2513150	best: 3.2513107 (2999)	total: 5m 28s	remaining: 10m 23s
# 3500:	learn: 3.1487164	test: 3.2498653	best: 3.2498545 (3492)	total: 6m 15s	remaining: 9m 17s
# 4000:	learn: 3.1275960	test: 3.2488347	best: 3.2488347 (3998)	total: 7m 2s	remaining: 8m 15s
# 4500:	learn: 3.1066260	test: 3.2481419	best: 3.2481313 (4490)	total: 7m 49s	remaining: 7m 17s
# 5000:	learn: 3.0862829	test: 3.2475679	best: 3.2475598 (4998)	total: 8m 37s	remaining: 6m 21s
# bestTest = 3.247385559
# bestIteration = 5246
# Shrink model to first 5247 iterations.
#   N trees =  5247
# Test score: 0.28746009561498165
# MSE:  10.544652021293969
# RMSE:  3.247252996194471
#        Actual  Predicted
# 15774       5   2.766027
# 5940        0   1.319857
# 18885       0   0.538117
# 273         8   0.750496
# 6663        0   3.719357
# 8723        0   0.641203
# 24954       0   0.820491
# 21245       0   3.145722
# 29471       5   3.761818
# 8153        0   0.528520
#
# Fold  1
# 0:	learn: 3.8399505	test: 3.8395751	best: 3.8395751 (0)	total: 79.1ms	remaining: 11m 27s
# 500:	learn: 3.3165660	test: 3.2778488	best: 3.2778488 (500)	total: 44.4s	remaining: 12m 5s
# 1000:	learn: 3.2741111	test: 3.2582129	best: 3.2582129 (1000)	total: 1m 29s	remaining: 11m 31s
# 1500:	learn: 3.2434650	test: 3.2504534	best: 3.2504534 (1500)	total: 2m 15s	remaining: 10m 51s
# 2000:	learn: 3.2180092	test: 3.2462362	best: 3.2462362 (2000)	total: 3m 2s	remaining: 10m 10s
# 2500:	learn: 3.1940095	test: 3.2429754	best: 3.2429733 (2499)	total: 3m 49s	remaining: 9m 28s
# 3000:	learn: 3.1707427	test: 3.2404869	best: 3.2404869 (3000)	total: 4m 36s	remaining: 8m 44s
# 3500:	learn: 3.1487212	test: 3.2389103	best: 3.2389072 (3490)	total: 5m 23s	remaining: 8m
# 4000:	learn: 3.1272094	test: 3.2375267	best: 3.2375267 (4000)	total: 6m 10s	remaining: 7m 15s
# 4500:	learn: 3.1073353	test: 3.2367371	best: 3.2367371 (4500)	total: 6m 57s	remaining: 6m 29s
# 5000:	learn: 3.0871423	test: 3.2359613	best: 3.2359471 (4994)	total: 7m 45s	remaining: 5m 43s
# 5500:	learn: 3.0671223	test: 3.2355032	best: 3.2354744 (5486)	total: 8m 33s	remaining: 4m 57s
# 6000:	learn: 3.0477686	test: 3.2348884	best: 3.2348884 (6000)	total: 9m 20s	remaining: 4m 11s
# 6500:	learn: 3.0286738	test: 3.2345106	best: 3.2344606 (6417)	total: 10m 7s	remaining: 3m 24s
# bestTest = 3.234460608
# bestIteration = 6417
# Shrink model to first 6418 iterations.
#   N trees =  6418
# Test score: 0.2931635372740562
# MSE:  10.460248597361383
# RMSE:  3.2342307582115075
#        Actual  Predicted
# 28219       6   6.754839
# 14224       0   0.932664
# 14405       0   3.527503
# 10374       0   0.150158
# 12344       7   4.666759
# 26620       0   0.014328
# 33996       0   0.588902
# 30213       0   1.941715
# 39145       8   6.639309
# 12904       0   2.184443
#
# Fold  2
# 0:	learn: 3.8400364	test: 3.8394754	best: 3.8394754 (0)	total: 75.6ms	remaining: 10m 57s
# 500:	learn: 3.3184614	test: 3.2691938	best: 3.2691938 (500)	total: 44.2s	remaining: 12m 3s
# 1000:	learn: 3.2753769	test: 3.2485625	best: 3.2485625 (1000)	total: 1m 29s	remaining: 11m 26s
# 1500:	learn: 3.2441863	test: 3.2401571	best: 3.2401571 (1500)	total: 2m 15s	remaining: 10m 47s
# 2000:	learn: 3.2168885	test: 3.2356091	best: 3.2356091 (2000)	total: 3m 1s	remaining: 10m 8s
# 2500:	learn: 3.1920301	test: 3.2327010	best: 3.2327010 (2500)	total: 3m 48s	remaining: 9m 26s
# 3000:	learn: 3.1687981	test: 3.2308502	best: 3.2308502 (3000)	total: 4m 35s	remaining: 8m 42s
# 3500:	learn: 3.1464987	test: 3.2292245	best: 3.2292204 (3498)	total: 5m 22s	remaining: 7m 58s
# 4000:	learn: 3.1251856	test: 3.2281748	best: 3.2281654 (3995)	total: 6m 9s	remaining: 7m 13s
# 4500:	learn: 3.1045002	test: 3.2275640	best: 3.2275460 (4474)	total: 6m 56s	remaining: 6m 28s
# 5000:	learn: 3.0848834	test: 3.2269621	best: 3.2269451 (4984)	total: 7m 43s	remaining: 5m 42s
# 5500:	learn: 3.0653376	test: 3.2264060	best: 3.2263906 (5482)	total: 8m 30s	remaining: 4m 56s
# 6000:	learn: 3.0465321	test: 3.2260382	best: 3.2260098 (5947)	total: 9m 17s	remaining: 4m 10s
# bestTest = 3.225967802
# bestIteration = 6041
# Shrink model to first 6042 iterations.
#   N trees =  6042
# Test score: 0.29684097787038355
# MSE:  10.405827320491676
# RMSE:  3.2258064604826613
#        Actual  Predicted
# 33208       4   3.773883
# 2402        0   2.098745
# 15235       0   0.693196
# 29856       9   5.000874
# 41863       0   1.549195
# 10880      10   6.772315
# 18964       9   1.849600
# 25017       1   6.176431
# 4500:	learn: 3.1076179	test: 3.2448879	best: 3.2448711 (4494)	total: 7m	remaining: 6m 31s
# 5000:	learn: 3.0873341	test: 3.2439517	best: 3.2439517 (5000)	total: 7m 47s	remaining: 5m 45s
# bestTest = 3.243806443
# bestIteration = 5051
# Shrink model to first 5052 iterations.
#   N trees =  5052
# Test score: 0.2890601769717225
# MSE:  10.521364537334913
# RMSE:  3.243665293666243
#        Actual  Predicted
# 15073       0   1.170919
# 32838       0   1.080153
# 9247        7   4.226430
# 29306       0   0.907423
# 5980        5   3.860142
# 29630       0   2.179361
# 31767       0   0.742506
# 1171        7   4.148714
# 22311      10   5.588770
# 33313       9   4.130766
#
# Fold  8
# 0:	learn: 3.8400156	test: 3.8394877	best: 3.8394877 (0)	total: 85.3ms	remaining: 12m 21s
# 500:	learn: 3.3183342	test: 3.2596748	best: 3.2596748 (500)	total: 44s	remaining: 11m 58s
# 1000:	learn: 3.2759214	test: 3.2402058	best: 3.2402058 (1000)	total: 1m 28s	remaining: 11m 23s
# 1500:	learn: 3.2446086	test: 3.2328444	best: 3.2328444 (1500)	total: 2m 14s	remaining: 10m 43s
# 2000:	learn: 3.2178514	test: 3.2287337	best: 3.2287337 (2000)	total: 3m	remaining: 10m 3s
# 2500:	learn: 3.1937527	test: 3.2261919	best: 3.2261919 (2500)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1706710	test: 3.2240993	best: 3.2240879 (2998)	total: 4m 33s	remaining: 8m 38s
# 3500:	learn: 3.1486416	test: 3.2226448	best: 3.2226448 (3500)	total: 5m 19s	remaining: 7m 54s
# 4000:	learn: 3.1278812	test: 3.2216897	best: 3.2216887 (3999)	total: 6m 6s	remaining: 7m 10s
# bestTest = 3.221231316
# bestIteration = 4357
# Shrink model to first 4358 iterations.
#   N trees =  4358
# Test score: 0.29893520782458316
# MSE:  10.37522164864735
# RMSE:  3.221059088040353
#        Actual  Predicted
# 38398       0   1.472343
# 19971       0   1.096441
# 23792       0   2.695067
# 15772       0   0.018162
# 37061       8   4.136775
# 4980        7   4.481986
# 35635       5   5.934026
# 38649       8   6.774729
# 4291        0   0.966963
# 27463      10   3.798070
#
# Fold  9
# 0:	learn: 3.8399912	test: 3.8395534	best: 3.8395534 (0)	total: 78.5ms	remaining: 11m 22s
# 500:	learn: 3.3155676	test: 3.2876847	best: 3.2876847 (500)	total: 44.3s	remaining: 12m 3s
# 1000:	learn: 3.2721191	test: 3.2687843	best: 3.2687843 (1000)	total: 1m 29s	remaining: 11m 25s
# 1500:	learn: 3.2419138	test: 3.2611906	best: 3.2611906 (1500)	total: 2m 14s	remaining: 10m 45s
# 2000:	learn: 3.2160525	test: 3.2566616	best: 3.2566616 (2000)	total: 3m	remaining: 10m 4s
# 2500:	learn: 3.1913254	test: 3.2537466	best: 3.2537448 (2499)	total: 3m 47s	remaining: 9m 23s
# 3000:	learn: 3.1687110	test: 3.2517897	best: 3.2517626 (2990)	total: 4m 34s	remaining: 8m 40s
# 3500:	learn: 3.1464857	test: 3.2502066	best: 3.2502058 (3498)	total: 5m 21s	remaining: 7m 56s
# 4000:	learn: 3.1249248	test: 3.2489658	best: 3.2489632 (3997)	total: 6m 7s	remaining: 7m 11s
# 4500:	learn: 3.1045255	test: 3.2480376	best: 3.2480060 (4480)	total: 6m 54s	remaining: 6m 26s
# 5000:	learn: 3.0834266	test: 3.2475463	best: 3.2475463 (5000)	total: 7m 41s	remaining: 5m 40s
# bestTest = 3.247318746
# bestIteration = 5199
# Shrink model to first 5200 iterations.
#   N trees =  5200
# Test score: 0.2875185611695602
# MSE:  10.54417926975766
# RMSE:  3.247180202846411
#        Actual  Predicted
# 7764        0   4.172859
# 33538       8   2.577966
# 15588       0   0.000000
# 43148       0   1.672802
# 13761       9   2.357856
# 25806       0   1.044163
# 31846       0   0.792028
# 121         0   3.146609
# 11171       0   4.239955
# 33937       0   4.319991
#
# Fold  10
# 0:	learn: 3.8400294	test: 3.8396026	best: 3.8396026 (0)	total: 76.2ms	remaining: 11m 2s
# 500:	learn: 3.3173364	test: 3.2762862	best: 3.2762862 (500)	total: 44.1s	remaining: 12m
# 1000:	learn: 3.2740680	test: 3.2568710	best: 3.2568710 (1000)	total: 1m 29s	remaining: 11m 25s
# 1500:	learn: 3.2430447	test: 3.2490128	best: 3.2490128 (1500)	total: 2m 14s	remaining: 10m 46s
# 2000:	learn: 3.2170445	test: 3.2447207	best: 3.2447199 (1998)	total: 3m 1s	remaining: 10m 5s
# 2500:	learn: 3.1922057	test: 3.2415951	best: 3.2415951 (2500)	total: 3m 47s	remaining: 9m 23s
# 3000:	learn: 3.1692205	test: 3.2395082	best: 3.2395082 (3000)	total: 4m 34s	remaining: 8m 40s
# 3500:	learn: 3.1476009	test: 3.2380589	best: 3.2380589 (3500)	total: 5m 20s	remaining: 7m 55s
# 4000:	learn: 3.1265447	test: 3.2371699	best: 3.2371699 (4000)	total: 6m 7s	remaining: 7m 10s
# 4500:	learn: 3.1060842	test: 3.2364425	best: 3.2364425 (4500)	total: 6m 54s	remaining: 6m 26s
# 5000:	learn: 3.0860558	test: 3.2358059	best: 3.2357999 (4992)	total: 7m 41s	remaining: 5m 40s
# bestTest = 3.235595539
# bestIteration = 5165
# Shrink model to first 5166 iterations.
#   N trees =  5166
# Test score: 0.2926856547823582
# MSE:  10.467699832767803
# RMSE:  3.2353824863171594
#        Actual  Predicted
# 27410       0   3.124857
# 11629       0   7.259942
# 3821        0   1.050451
# 8554        0   7.927440
# 36583       7   0.933314
# 33638       0   0.183483
# 26781       0   4.246151
# 24634      10   2.731488
# 32236       0   2.822275
# 26949       0   0.251616
#
# Fold  11
# 0:	learn: 3.8400409	test: 3.8396164	best: 3.8396164 (0)	total: 83.7ms	remaining: 12m 7s
# 500:	learn: 3.3162729	test: 3.2879552	best: 3.2879552 (500)	total: 44.1s	remaining: 12m 1s
# 1000:	learn: 3.2749786	test: 3.2692605	best: 3.2692605 (1000)	total: 1m 28s	remaining: 11m 23s
# 1500:	learn: 3.2453544	test: 3.2618902	best: 3.2618902 (1500)	total: 2m 14s	remaining: 10m 43s
# 2000:	learn: 3.2190549	test: 3.2576003	best: 3.2576003 (2000)	total: 3m	remaining: 10m 3s
# 2500:	learn: 3.1953942	test: 3.2549186	best: 3.2549186 (2500)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1724710	test: 3.2528703	best: 3.2528619 (2989)	total: 4m 33s	remaining: 8m 38s
# 3500:	learn: 3.1499115	test: 3.2515429	best: 3.2515376 (3499)	total: 5m 19s	remaining: 7m 54s
# 4000:	learn: 3.1288619	test: 3.2504721	best: 3.2504559 (3981)	total: 6m 6s	remaining: 7m 10s
# 4500:	learn: 3.1075409	test: 3.2497640	best: 3.2497612 (4496)	total: 6m 54s	remaining: 6m 25s
# 5000:	learn: 3.0868830	test: 3.2492267	best: 3.2492187 (4996)	total: 7m 41s	remaining: 5m 40s
# bestTest = 3.248905313
# bestIteration = 5384
# Shrink model to first 5385 iterations.
#   N trees =  5385
# Test score: 0.28679273410071404
# MSE:  10.554316138385925
# RMSE:  3.2487407003923727
#        Actual  Predicted
# 30734       0   2.605047
# 11536       0   0.316749
# 6841       10   2.451989
# 34537       0   0.736907
# 23012       0   2.091627
# 21624       0   2.852258
# 32193       8   4.397013
# 20564       0   3.024829
# 27458       0   4.685701
# 17894       0   1.751229
#
# Fold  12
# 0:	learn: 3.8399974	test: 3.8394793	best: 3.8394793 (0)	total: 75.8ms	remaining: 10m 59s
# 500:	learn: 3.3170189	test: 3.2737967	best: 3.2737967 (500)	total: 44.2s	remaining: 12m 2s
# 1000:	learn: 3.2739384	test: 3.2544237	best: 3.2544237 (1000)	total: 1m 28s	remaining: 11m 23s
# 1500:	learn: 3.2432719	test: 3.2466983	best: 3.2466983 (1500)	total: 2m 14s	remaining: 10m 45s
# 2000:	learn: 3.2168363	test: 3.2424708	best: 3.2424648 (1999)	total: 3m	remaining: 10m 4s
# 2500:	learn: 3.1927593	test: 3.2395508	best: 3.2395467 (2499)	total: 3m 47s	remaining: 9m 23s
# 3000:	learn: 3.1697684	test: 3.2375671	best: 3.2375624 (2998)	total: 4m 34s	remaining: 8m 39s
# 3500:	learn: 3.1478725	test: 3.2362492	best: 3.2362446 (3495)	total: 5m 20s	remaining: 7m 55s
# 4000:	learn: 3.1269314	test: 3.2350743	best: 3.2350743 (4000)	total: 6m 7s	remaining: 7m 11s
# 4500:	learn: 3.1067880	test: 3.2343704	best: 3.2343673 (4492)	total: 6m 54s	remaining: 6m 26s
# 5000:	learn: 3.0865966	test: 3.2336939	best: 3.2336936 (4998)	total: 7m 41s	remaining: 5m 40s
# 5500:	learn: 3.0667413	test: 3.2331426	best: 3.2331426 (5500)	total: 8m 28s	remaining: 4m 55s
# bestTest = 3.232931957
# bestIteration = 5650
# Shrink model to first 5651 iterations.
#   N trees =  5651
# Test score: 0.29378104796000226
# MSE:  10.450900375154472
# RMSE:  3.232785234925833
#        Actual  Predicted
# 32335       7   3.317331
# 9079        0   2.576846
# 27329      10   5.117148
# 11360       8   2.930088
# 18434       0   5.181933
# 23181       0   2.528793
# 13748       0   0.297965
# 11563      10   1.499643
# 12599       6   4.476705
# 4293        0   4.221495
#
# Fold  13
# 0:	learn: 3.8400320	test: 3.8396050	best: 3.8396050 (0)	total: 81.4ms	remaining: 11m 47s
# 500:	learn: 3.3160243	test: 3.2836240	best: 3.2836240 (500)	total: 44s	remaining: 11m 59s
# 1000:	learn: 3.2730051	test: 3.2659125	best: 3.2659125 (1000)	total: 1m 28s	remaining: 11m 23s
# 1500:	learn: 3.2424836	test: 3.2589801	best: 3.2589801 (1500)	total: 2m 14s	remaining: 10m 42s
# 2000:	learn: 3.2158971	test: 3.2549779	best: 3.2549779 (2000)	total: 3m	remaining: 10m 2s
# 2500:	learn: 3.1914393	test: 3.2521861	best: 3.2521861 (2500)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1683542	test: 3.2502225	best: 3.2502225 (3000)	total: 4m 33s	remaining: 8m 38s
# 3500:	learn: 3.1464226	test: 3.2488966	best: 3.2488455 (3467)	total: 5m 20s	remaining: 7m 54s
# 4000:	learn: 3.1250876	test: 3.2480293	best: 3.2480256 (3995)	total: 6m 7s	remaining: 7m 10s
# 4500:	learn: 3.1049841	test: 3.2471217	best: 3.2471066 (4495)	total: 6m 54s	remaining: 6m 25s
# 5000:	learn: 3.0850500	test: 3.2463160	best: 3.2463160 (5000)	total: 7m 40s	remaining: 5m 40s
# bestTest = 3.245918474
# bestIteration = 5379
# Shrink model to first 5380 iterations.
#   N trees =  5380
# Test score: 0.28809777135577375
# MSE:  10.535191345572866
# RMSE:  3.245795949466458
#        Actual  Predicted
# 34061       8   4.837405
# 11444       0   2.699638
# 41032       0   0.545934
# 9350        8   6.223300
# 6778        6   5.494740
# 26943       0   0.207570
# 7993        0   1.616638
# 11944       0   0.494078
# 27044       0   0.001481
# 33248       7   3.211601
#
# Fold  14
# 0:	learn: 3.8400603	test: 3.8395355	best: 3.8395355 (0)	total: 75.9ms	remaining: 10m 59s
# 500:	learn: 3.3170518	test: 3.2725812	best: 3.2725812 (500)	total: 44.2s	remaining: 12m 3s
# 1000:	learn: 3.2744482	test: 3.2529148	best: 3.2529148 (1000)	total: 1m 29s	remaining: 11m 26s
# 1500:	learn: 3.2436247	test: 3.2449746	best: 3.2449746 (1500)	total: 2m 15s	remaining: 10m 47s
# 2000:	learn: 3.2173129	test: 3.2406015	best: 3.2405955 (1994)	total: 3m	remaining: 10m 5s
# 2500:	learn: 3.1929361	test: 3.2376051	best: 3.2376051 (2500)	total: 3m 47s	remaining: 9m 24s
# 3000:	learn: 3.1702384	test: 3.2354597	best: 3.2354597 (3000)	total: 4m 34s	remaining: 8m 40s
# 3500:	learn: 3.1484781	test: 3.2340740	best: 3.2340666 (3493)	total: 5m 21s	remaining: 7m 56s
# 4000:	learn: 3.1266360	test: 3.2325744	best: 3.2325670 (3998)	total: 6m 7s	remaining: 7m 11s
# 4500:	learn: 3.1061876	test: 3.2315105	best: 3.2315105 (4500)	total: 6m 54s	remaining: 6m 26s
# 5000:	learn: 3.0855807	test: 3.2306695	best: 3.2306574 (4993)	total: 7m 41s	remaining: 5m 40s
# 5500:	learn: 3.0658760	test: 3.2301718	best: 3.2301396 (5488)	total: 8m 27s	remaining: 4m 54s
# 6000:	learn: 3.0468166	test: 3.2296170	best: 3.2296170 (6000)	total: 9m 15s	remaining: 4m 9s
# 6500:	learn: 3.0278192	test: 3.2292889	best: 3.2292546 (6487)	total: 10m 2s	remaining: 3m 23s
# 7000:	learn: 3.0091565	test: 3.2289088	best: 3.2288900 (6993)	total: 10m 49s	remaining: 2m 37s
# 7500:	learn: 2.9908906	test: 3.2285410	best: 3.2285123 (7460)	total: 11m 36s	remaining: 1m 50s
# 8000:	learn: 2.9729560	test: 3.2282864	best: 3.2282731 (7990)	total: 12m 23s	remaining: 1m 4s
# bestTest = 3.228273063
# bestIteration = 7990
# Shrink model to first 7991 iterations.
#   N trees =  7991
# Test score: 0.2959246560153054
# MSE:  10.419364025176733
# RMSE:  3.2279039677748678
#        Actual  Predicted
# 19360       6   4.734688
# 11643       5   6.420402
# 8116        0   2.294488
# 39744       0   2.294682
# 8207       10   2.488341
# 36380       4   3.504613
# 26872       0   0.194772
# 15073       0   3.733857
# 14281       0   1.199787
# 18766       0   0.295870
#
# Fold  15
# 0:	learn: 3.8400653	test: 3.8394042	best: 3.8394042 (0)	total: 77.8ms	remaining: 11m 15s
# 500:	learn: 3.3175833	test: 3.2669521	best: 3.2669521 (500)	total: 44.2s	remaining: 12m 2s
# 1000:	learn: 3.2755177	test: 3.2474268	best: 3.2474268 (1000)	total: 1m 28s	remaining: 11m 21s
# 1500:	learn: 3.2451754	test: 3.2400342	best: 3.2400342 (1500)	total: 2m 14s	remaining: 10m 42s
# 2000:	learn: 3.2190818	test: 3.2360415	best: 3.2360146 (1996)	total: 3m	remaining: 10m 3s
# 2500:	learn: 3.1933791	test: 3.2329614	best: 3.2329614 (2500)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1705959	test: 3.2311315	best: 3.2311315 (3000)	total: 4m 33s	remaining: 8m 38s
# 3500:	learn: 3.1489210	test: 3.2295033	best: 3.2295023 (3498)	total: 5m 20s	remaining: 7m 54s
# 4000:	learn: 3.1279865	test: 3.2284090	best: 3.2283873 (3988)	total: 6m 6s	remaining: 7m 10s
# 4500:	learn: 3.1075544	test: 3.2272948	best: 3.2272941 (4499)	total: 6m 53s	remaining: 6m 25s
# 5000:	learn: 3.0872676	test: 3.2264809	best: 3.2264809 (5000)	total: 7m 40s	remaining: 5m 39s
# 5500:	learn: 3.0677457	test: 3.2258457	best: 3.2258430 (5498)	total: 8m 27s	remaining: 4m 54s
# bestTest = 3.225439932
# bestIteration = 5717
# Shrink model to first 5718 iterations.
#   N trees =  5718
# Test score: 0.2970505532391631
# MSE:  10.402650556625451
# RMSE:  3.2253140244983047
#        Actual  Predicted
# 24313       7   3.373700
# 9296        0   0.067028
# 24532       9   2.224489
# 2806        9   2.235194
# 6779        0   2.916120
# 37035       9   3.497685
# 16622       0   1.420127
# 10335      10   8.411600
# 24186       8   1.584641
# 12167       8   3.303428
#
# Fold  16
# 0:	learn: 3.8400252	test: 3.8395682	best: 3.8395682 (0)	total: 75.5ms	remaining: 10m 56s
# 500:	learn: 3.3158811	test: 3.2850446	best: 3.2850446 (500)	total: 43.7s	remaining: 11m 54s
# 1000:	learn: 3.2731802	test: 3.2658539	best: 3.2658539 (1000)	total: 1m 28s	remaining: 11m 19s
# 1500:	learn: 3.2426544	test: 3.2578363	best: 3.2578363 (1500)	total: 2m 13s	remaining: 10m 40s
# 2000:	learn: 3.2165097	test: 3.2527181	best: 3.2527181 (2000)	total: 3m	remaining: 10m 2s
# 2500:	learn: 3.1918153	test: 3.2491904	best: 3.2491904 (2500)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1688026	test: 3.2464174	best: 3.2464078 (2998)	total: 4m 33s	remaining: 8m 38s
# 3500:	learn: 3.1472889	test: 3.2444288	best: 3.2444288 (3500)	total: 5m 19s	remaining: 7m 54s
# 4000:	learn: 3.1259468	test: 3.2429077	best: 3.2429077 (4000)	total: 6m 6s	remaining: 7m 10s
# 4500:	learn: 3.1053952	test: 3.2418678	best: 3.2418404 (4492)	total: 6m 53s	remaining: 6m 24s
# 5000:	learn: 3.0861714	test: 3.2408828	best: 3.2408707 (4996)	total: 7m 40s	remaining: 5m 39s
# 5500:	learn: 3.0666115	test: 3.2402573	best: 3.2402573 (5500)	total: 8m 26s	remaining: 4m 54s
# 6000:	learn: 3.0474194	test: 3.2395468	best: 3.2395342 (5994)	total: 9m 13s	remaining: 4m 8s
# 6500:	learn: 3.0286175	test: 3.2390178	best: 3.2389904 (6482)	total: 10m	remaining: 3m 22s
# 7000:	learn: 3.0098361	test: 3.2385889	best: 3.2385882 (6998)	total: 10m 47s	remaining: 2m 36s
# bestTest = 3.238328646
# bestIteration = 7294
# Shrink model to first 7295 iterations.
#   N trees =  7295
# Test score: 0.29146319885925065
# MSE:  10.485335443025305
# RMSE:  3.2381067683177625
#        Actual  Predicted
# 15233       0   0.338329
# 5199        0   5.243519
# 12520       0   0.956408
# 27821       0   4.240001
# 28679       0   5.573429
# 15429      10   1.413941
# 23323       5   4.435145
# 8602        0   0.066936
# 7999        0   1.527319
# 31846       0   5.447330
#
# Fold  17
# 0:	learn: 3.8400771	test: 3.8394735	best: 3.8394735 (0)	total: 75.2ms	remaining: 10m 53s
# 500:	learn: 3.3178236	test: 3.2646240	best: 3.2646240 (500)	total: 44.1s	remaining: 12m 1s
# 1000:	learn: 3.2751114	test: 3.2443273	best: 3.2443273 (1000)	total: 1m 28s	remaining: 11m 23s
# 1500:	learn: 3.2448441	test: 3.2359686	best: 3.2359686 (1500)	total: 2m 14s	remaining: 10m 43s
# 2000:	learn: 3.2187551	test: 3.2315407	best: 3.2315387 (1998)	total: 3m	remaining: 10m 3s
# 2500:	learn: 3.1952385	test: 3.2286125	best: 3.2286080 (2499)	total: 3m 46s	remaining: 9m 21s
# 3000:	learn: 3.1722824	test: 3.2260397	best: 3.2260397 (3000)	total: 4m 33s	remaining: 8m 39s
# 3500:	learn: 3.1502741	test: 3.2242740	best: 3.2242740 (3500)	total: 5m 20s	remaining: 7m 55s
# 4000:	learn: 3.1289369	test: 3.2230120	best: 3.2230075 (3998)	total: 6m 6s	remaining: 7m 10s
# 4500:	learn: 3.1082833	test: 3.2219500	best: 3.2219500 (4500)	total: 6m 53s	remaining: 6m 25s
# 5000:	learn: 3.0879754	test: 3.2212790	best: 3.2212579 (4981)	total: 7m 40s	remaining: 5m 39s
# 5500:	learn: 3.0681475	test: 3.2207077	best: 3.2207007 (5499)	total: 8m 27s	remaining: 4m 54s
# bestTest = 3.220562368
# bestIteration = 5689
# Shrink model to first 5690 iterations.
#   N trees =  5690
# Test score: 0.29920499240893805
# MSE:  10.370649559765976
# RMSE:  3.220349291577852
#        Actual  Predicted
# 8098        0   0.410407
# 13227       8   3.541848
# 29229       5   3.513852
# 35874       0   0.044774
# 18487       8   5.231690
# 38162       8   5.217137
# 6150        0   0.765428
# 8182        9   4.880424
# 13721       0   4.623751
# 41700       0   4.706108
#
# Fold  18
# 0:	learn: 3.8400422	test: 3.8395762	best: 3.8395762 (0)	total: 75.6ms	remaining: 10m 57s
# 500:	learn: 3.3160693	test: 3.2824884	best: 3.2824884 (500)	total: 44s	remaining: 12m
# 1000:	learn: 3.2738710	test: 3.2643302	best: 3.2643302 (1000)	total: 1m 28s	remaining: 11m 20s
# 1500:	learn: 3.2429114	test: 3.2568109	best: 3.2568109 (1500)	total: 2m 13s	remaining: 10m 41s
# 2000:	learn: 3.2158269	test: 3.2522555	best: 3.2522545 (1999)	total: 2m 59s	remaining: 10m 1s
# 2500:	learn: 3.1905873	test: 3.2491727	best: 3.2491727 (2500)	total: 3m 47s	remaining: 9m 22s
# 3000:	learn: 3.1666892	test: 3.2469255	best: 3.2469242 (2999)	total: 4m 34s	remaining: 8m 40s
# 3500:	learn: 3.1455126	test: 3.2454950	best: 3.2454906 (3499)	total: 5m 21s	remaining: 7m 56s
# 4000:	learn: 3.1239223	test: 3.2445257	best: 3.2445217 (3999)	total: 6m 7s	remaining: 7m 11s
# 4500:	learn: 3.1032035	test: 3.2435750	best: 3.2435720 (4498)	total: 6m 53s	remaining: 6m 25s
# 5000:	learn: 3.0830914	test: 3.2427607	best: 3.2427579 (4978)	total: 7m 41s	remaining: 5m 40s
# bestTest = 3.242572688
# bestIteration = 5155
# Shrink model to first 5156 iterations.
#   N trees =  5156
# Test score: 0.2895530721144677
# MSE:  10.513482602051509
# RMSE:  3.2424500924534687
#        Actual  Predicted
# 41869       8   5.101808
# 16985       0   2.751678
# 25737       5   5.033868
# 9123        8   4.356406
# 30504       0   1.736892
# 7082        0   1.120357
# 11471       8   3.989329
# 31585       9   6.349040
# 18078       0   1.546389
# 36818      10   5.549965
#
# Fold  19
# 0:	learn: 3.8400572	test: 3.8396435	best: 3.8396435 (0)	total: 76.2ms	remaining: 11m 1s
# 500:	learn: 3.3167699	test: 3.2924786	best: 3.2924786 (500)	total: 44.5s	remaining: 12m 8s
# 1000:	learn: 3.2744157	test: 3.2735853	best: 3.2735853 (1000)	total: 1m 29s	remaining: 11m 24s
# 1500:	learn: 3.2436118	test: 3.2659917	best: 3.2659916 (1499)	total: 2m 14s	remaining: 10m 43s
# 2000:	learn: 3.2167521	test: 3.2617050	best: 3.2617050 (2000)	total: 3m 1s	remaining: 10m 7s
# 2500:	learn: 3.1927740	test: 3.2588167	best: 3.2588167 (2500)	total: 3m 49s	remaining: 9m 28s
# 3000:	learn: 3.1695134	test: 3.2568396	best: 3.2568396 (3000)	total: 4m 38s	remaining: 8m 47s
# 3500:	learn: 3.1475959	test: 3.2558867	best: 3.2558740 (3498)	total: 5m 25s	remaining: 8m 2s
# 4000:	learn: 3.1261283	test: 3.2546716	best: 3.2546713 (3995)	total: 6m 12s	remaining: 7m 17s
# 4500:	learn: 3.1057227	test: 3.2538792	best: 3.2538792 (4500)	total: 7m	remaining: 6m 31s
# 5000:	learn: 3.0853831	test: 3.2534527	best: 3.2534148 (4918)	total: 7m 47s	remaining: 5m 45s
# bestTest = 3.253414758
# bestIteration = 4918
# Shrink model to first 4919 iterations.
#   N trees =  4919
# Test score: 0.2848103072296263
# MSE:  10.583667965862999
# RMSE:  3.2532549801488044
#        Actual  Predicted
# 3514        0   1.699533
# 26316       0   1.932154
# 30714       0   3.506562
# 5300        0   1.682515
# 6776        0   1.699590
# 21715       0   0.100015
# 863         0   5.763594
# 11804       9   5.818710
# 2087        7   3.219045
# 11667       0   1.647029

# %%
sub = pd.DataFrame()
sub['ID'] = test['ID']
sub['Book-Rating'] = y_test_pred
sub
# Out:
#                  ID  Book-Rating
# 0       TEST_000000     5.530954
# 1       TEST_000001     6.501299
# 2       TEST_000002     6.203025
# 3       TEST_000003     5.880463
# 4       TEST_000004     5.655802
# ...             ...          ...
# 159616  TEST_159616     3.667640
# 159617  TEST_159617     3.348060
# 159618  TEST_159618     4.021934
# 159619  TEST_159619     3.738853
# 159620  TEST_159620     4.133861
#
# [159621 rows x 2 columns]

# %%
import seaborn as sns
sns.histplot(sub['Book-Rating'])
# Out:
# <Axes: xlabel='Book-Rating', ylabel='Count'>

# %%
sub.to_csv('submit_cat+20-folds.csv', index=False,encoding="utf-8-sig")
