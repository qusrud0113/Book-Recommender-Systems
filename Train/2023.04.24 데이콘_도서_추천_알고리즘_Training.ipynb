# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf


#티스토리 업로드시 최적화 코드
#from IPython.core.display import display, HTML
#display(HTML("<style>.container {width:90% !important;}</style>"))

# %% [markdown]
# # 2023.04.17
# # TRAINING
# Dataset Info.
#
# train.csv [파일]
#
#     ID : 샘플 고유 ID
#     User-ID : 유저 고유 ID
#     Book-ID : 도서 고유 ID
#     유저 정보
#     Age : 나이
#     Location : 지역
#     도서 정보
#     Book-Title : 도서 명
#     Book-Author : 도서 저자
#     Year-Of-Publication : 도서 출판 년도 (-1일 경우 결측 혹은 알 수 없음)
#     Publisher : 출판사
#     Book-Rating : 유저가 도서에 부여한 평점 (0점 ~ 10점)
#
#
# test.csv [파일]
#
#     ID : 샘플 고유 ID
#     User-ID : 유저 고유 ID
#     Book-ID : 도서 고유 ID
#     유저 정보
#     Age : 나이
#     Location : 지역
#     도서 정보
#     Book-Title : 도서 명
#     Book-Author : 도서 저자
#     Year-Of-Publication : 도서 출판 년도 (-1일 경우 결측 혹은 알 수 없음)
#     Publisher : 출판사
#
#
# sample_submission.csv [제출양식]
#
#     ID : 샘플 고유 ID
#     Book-Rating : 예측한 유저가 도서에 부여할 평점

# %%
import pandas as pd

# %%
import numpy as np
import random
import os
import gc

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) # Seed 고정

# %%
def csv_to_parquet(csv_path, save_name):
    df = pd.read_csv(csv_path)
    df.to_parquet(f'./{save_name}.parquet')
    del df
    gc.collect()
    print(save_name, 'Done.')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv( 'test.csv')
sample_submission = pd.read_csv('sample_submission.csv', index_col = 0)

# %%
train.head(10)
# Out:
#              ID     User-ID      Book-ID  Book-Rating   Age  \
# 0  TRAIN_000000  USER_00000  BOOK_044368            8  23.0
# 1  TRAIN_000001  USER_00000  BOOK_081205            8  23.0
# 2  TRAIN_000002  USER_00000  BOOK_086781            0  23.0
# 3  TRAIN_000003  USER_00000  BOOK_098622            0  23.0
# 4  TRAIN_000004  USER_00000  BOOK_180810            8  23.0
# 5  TRAIN_000005  USER_00000  BOOK_206799            5  23.0
# 6  TRAIN_000006  USER_00000  BOOK_239414            9  23.0
# 7  TRAIN_000007  USER_00000  BOOK_269070            0  23.0
# 8  TRAIN_000008  USER_00001  BOOK_190739            7  35.0
# 9  TRAIN_000009  USER_00001  BOOK_210079            0  35.0
#
#                            Location  \
# 0  sackville, new brunswick, canada
# 1  sackville, new brunswick, canada
# 2  sackville, new brunswick, canada
# 3  sackville, new brunswick, canada
# 4  sackville, new brunswick, canada
# 5  sackville, new brunswick, canada
# 6  sackville, new brunswick, canada
# 7  sackville, new brunswick, canada
# 8  wake forest, north carolina, usa
# 9  wake forest, north carolina, usa
#
#                                           Book-Title  \
# 0                                         Road Taken
# 1                  Macbeth (New Penguin Shakespeare)
# 2                 Waverley (Penguin English Library)
# 3                            Mother Earth Father Sky
# 4                                  She Who Remembers
# 5                 Neuromancer (Remembering Tomorrow)
# 6                                  The Little Prince
# 7                     Forests of the Heart (Newford)
# 8  Self Matters : Creating Your Life from the Ins...
# 9  The Self Matters Companion : Helping You Creat...
#
#                  Book-Author  Year-Of-Publication      Publisher
# 0                 Rona Jaffe               2001.0           Mira
# 1        William Shakespeare               1981.0  Penguin Books
# 2               Walter Scott               1981.0  Penguin Books
# 3               Sue Harrison               1991.0           Avon
# 4           Linda Lay Shuler               1989.0    Signet Book
# 5             William Gibson               1995.0      Ace Books
# 6  Antoine de Saint-ExupÃ©ry               1982.0  Harvest Books
# 7            Charles de Lint               2001.0      Tor Books
# 8          Phillip C. McGraw               2001.0     Free Press
# 9          Phillip C. McGraw               2002.0     Free Press

# %%
train[['User-ID','Location']].drop_duplicates().groupby(['User-ID'])['Location'].count().sort_values()
# Out:
# User-ID
# USER_00000    1
# USER_61443    1
# USER_61442    1
# USER_61441    1
# USER_61440    1
#              ..
# USER_30605    1
# USER_30604    1
# USER_30603    1
# USER_30622    1
# USER_92100    1
# Name: Location, Length: 83256, dtype: int64

# %% [markdown]
# User-ID를 기준으로 Location은 고유의 값이라는 것을 확인 할 수 있습니다. 즉, 평가를 해주는 유저의 지역은 고유의 값입니다.

# %%
train['City'] = [(i.split(',')[0]).lstrip().title() for i in train['Location']]
train['State'] = [(i.split(',')[1]).lstrip().title() for i in train['Location']]
train['Country'] = [(i.split(',')[2]).lstrip().title() for i in train['Location']]

# %%
test['City'] = [(i.split(',')[0]).lstrip().title() for i in test['Location']]
test['State'] = [(i.split(',')[1]).lstrip().title() for i in test['Location']]
test['Country'] = [(i.split(',')[2]).lstrip().title() for i in test['Location']]

# %%
train['City'].unique()
# Out:
# array(['Sackville', 'Wake Forest', 'Minneapolis', ..., 'Hampton Cove',
#        'Vancouver/ Richmond', 'Castiglion Fiorentino'], dtype=object)

# %%
train['State'].unique()
# Out:
# array(['New Brunswick', 'North Carolina', 'Minnesota', ..., 'Shetland',
#        'Wanganui', 'Vaucluse'], dtype=object)

# %%
train['Country'].unique()
# Out:
# array(['Canada', 'Usa', 'Germany', 'Spain', 'Australia', 'United Kingdom',
#        '', 'Italy', 'Netherlands', 'Portugal', 'Sweden', 'Austria',
#        'France', 'Finland', 'New Zealand', 'Singapore', 'Switzerland',
#        'Philippines', 'New York', 'España', 'Malaysia', 'Belgium',
#        'Japan', 'Denmark', 'Belize', 'England', 'Poland', 'Ireland',
#        'Haiti', 'Trinidad And Tobago', 'Lk Ammerland', 'Tanzania',
#        'Moldova', 'North Carolina', 'Bulgaria', 'Luxembourg',
#        'South Africa', 'Czech Republic', 'Tennessee', 'Israel', 'Malta',
#        'Petrolwar Nation', 'Kuwait', 'Peru', 'Ecuador', 'South Korea',
#        'Virginia', 'Turkey', 'Nigeria', 'British Columbia', 'Brazil',
#        'Missouri', 'Hungary', 'Indonesia', 'Kazakhstan', 'India', 'China',
#        'Egypt', 'Croatia', 'Taiwan', 'Argentina', 'California',
#        'Queensland', 'Ontario', 'Chile', 'Deutschland', 'Venezuela',
#        'Galiza', 'Iceland', 'Illinois', 'Scotland', 'New Jersey',
#        'Bolivia', 'Lithuania', 'Florida', 'Bayern', 'Victoria', 'Norway',
#        'N/A', 'Oregon', 'Mexico', 'Bahamas', 'Arkansas', 'United Sates',
#        'Romania', 'Iran', 'New Mexico', 'Dominican Republic', 'Maricopa',
#        'Usa Now', 'West Yorkshire', 'Andorra', 'Galiza Neghra', 'Jersey',
#        'Dc', 'Ghana', 'Richmond Country', 'United Arab Emirates',
#        'Tunisia', 'Papua New Guinea', 'Catalunya', 'Costa Rica',
#        'Vietnam', 'La Chine Éternelle!', 'Sri Lanka', 'Slovenia', 'Texas',
#        'Universe', 'Slovakia', 'Greece', 'Lleida', 'La Chine Éternelle !',
#        'Framingham', 'Puerto Rico', 'Nova Scotia', 'Grenada', 'Maryland',
#        'Cameroon', 'Usa (Currently Living In England)', 'Alderney',
#        'Saint Loius', 'Washington', 'Newfoundland', 'Maine', 'Laos',
#        'New Brunswick', 'Collin', 'Indiana', 'Burma', 'Thailand',
#        'Shelby', 'Hong Kong', 'New South Wales', 'Tdzimi', 'Space',
#        'Worcester', 'Ethiopia', 'South Dakota', 'Zambia',
#        'Los Estados Unidos De Norte America', 'Russia', 'United States',
#        'Massachusetts', 'Ohio', 'V9V 1H4', 'Antarctica', 'Tn', 'Polk',
#        'In Europe', 'U.A.E', 'North Yorkshire', 'Cambodia', 'Nz',
#        'Travelling....', 'Zimbabwe', 'Here And There', 'U.S.A.', 'Hawaii',
#        'Cherokee', 'Michigan', 'Cananda', 'South Australia',
#        'South Island', 'Pennsylvania', 'Monaco', 'Bourgogne', 'Morgan',
#        'Pontevedra', '"N/A"', 'Montana', 'Connecticut', 'Jamaica',
#        'Quebec', 'Wales', 'Pakistan', 'North Sumatera', 'Mongolia', 'Uk',
#        'Antigua And Barbuda', 'Alberta', 'Cyprus', 'Estonia', 'Barbados',
#        'Nepal', 'Ukraine', 'Pender', 'Us', 'Saint Lucia', 'Kenya',
#        'Guernsey', 'D.C.', 'Euskal Herria', 'Yugoslavia', 'Morocco',
#        'Bosnia And Herzegovina', 'Colombia', 'Ventura County', 'Csa',
#        'Hernando', 'Cape Verde', 'Oeiras', 'Cambridgeshire', 'Latvia',
#        'Prince William', 'X', 'Kern', 'Onondaga Nation', 'Guatemala',
#        'Co. Carlow', 'Canary Islands', 'Aruba', 'Saudi Arabia',
#        'We`Re Global!', 'Wisconsin', 'West Indies', 'Catalonia', 'Paris',
#        'Urugua', 'Gipuzkoa', 'Turkmenistan', 'Stadt', 'Panama',
#        'Uzbekistan', 'Bermuda', 'North Dakota', 'Kedah', 'Oman',
#        'Phillipines', 'Idaho', 'San Mateo', 'Uruguay', 'Unknown',
#        'Burkina Faso', 'Minnesota', 'Madagascar', 'Georgia', 'Benin',
#        'United State', 'Afghanistan', 'Pais Vasco', 'Bangladesh', 'Fiji',
#        'Italia', 'Berguedà', 'Paraguay', 'Colorado', 'Metro Manila',
#        'Albania', 'Ferrara', 'Nevada', 'Gabon', 'L`Italia',
#        'Rhode Island', 'Saskatchewan', 'Baden-Wuerttemberg',
#        'Cayman Islands', 'Macau', 'Yu-Song', 'Arizona',
#        'Marshall Islands', 'Rwanda', 'Niger', 'Almería', 'Ysa',
#        'Mauritius', 'Macedonia', 'Andalucia', 'Berlin', 'Palau',
#        'Australian Capital Territory', 'Qatar', 'New Hampshire',
#        'N/A - On The Road', 'Kansas', 'The Great White North', 'Seoul',
#        'Cuba', 'Algeria', 'United Kindgonm', 'Aberdeenshire', 'Brunei',
#        'Solomon Islands', 'Caribbean Sea', 'K1C7B1', 'St.Gallen',
#        'St.Thomasi', 'Okinawa', 'County Galway', 'Guinea-Bissau', 'Iraq',
#        'Eu', 'Middlesex', 'Catalunya Spain', 'Lebanon', 'Alabama',
#        'Hagiwara', 'Shanghai', 'La Belgique', 'Aroostook', 'Rutherford',
#        'Oklahoma', 'Honduras', 'Tasmania', 'El Salvador', 'Otago',
#        'Gambia', 'Fort Bend', '61 Men', 'Syria', 'Mozambique',
#        'Far Away...', 'U.K.', 'Álava', 'Quit', 'County Cork', 'Madrid',
#        'Guinea', 'Orense', 'Bc', 'St. Helena', 'Hungary And Usa',
#        'Etelä-Suomi', 'C', 'La France', 'Everywhere And Anywhere',
#        'Nebraska', 'Disrito Federal', 'U.S. Of A.', 'Uganda',
#        'Niedersachsen', 'United Staes', 'Ee.Uu', 'Zapopan', 'Alachua',
#        'Francisco Morazan', 'Venezia Giulia', 'Tajikistan', 'Burlington',
#        'Van Wert', 'Alaska', 'Camden', 'Bahrain', 'Austin', 'Ca.',
#        'Ile De France', 'U.S>', 'America', 'District Of Columbia'],
#       dtype=object)

# %% [markdown]
# Location을 ','로 나누면 첫 단어가 도시, 두번째가 State(주), 마지막 단어가 나라입니다. 해당 열을 새로 만들어줍니다.

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catboost in /usr/local/lib/python3.9/dist-packages (1.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)

# %%
# BERTopic 속도 향상을 위한 작업
# !pip install --extra-index-url https://download.pytorch.org/whl/cu117 --extra-index-url https://pypi.nvidia.com git+https://github.com/facebookresearch/dinov2
# 토픽 모델링을 위한 버토픽(BERTopic) 다운
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu117, https://pypi.nvidia.com
# Collecting git+https://github.com/facebookresearch/dinov2
#   Cloning https://github.com/facebookresearch/dinov2 to /tmp/pip-req-build-9e6s639x
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/dinov2 /tmp/pip-req-build-9e6s639x
#   Resolved https://github.com/facebookresearch/dinov2 to commit f8969297dbe53373b4041bf47d997a8dcc8d2077
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cuml-cu11
#   Downloading https://pypi.nvidia.com/cuml-cu11/cuml_cu11-23.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1111.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 GB 1.4 MB/s eta 0:00:00
# Collecting submitit
#   Downloading submitit-1.4.5-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 9.5 MB/s eta 0:00:00
# Collecting xformers==0.0.18
#   Downloading xformers-0.0.18-cp39-cp39-manylinux2014_x86_64.whl (123.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 MB 10.9 MB/s eta 0:00:00
# Collecting torchvision==0.15.0
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.15.0%2Bcu117-cp39-cp39-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 47.8 MB/s eta 0:00:00
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.4 MB/s eta 0:00:00
# Collecting torchmetrics==0.10.3
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dinov2==0.0.1) (2.0.0+cu118)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->dinov2==0.0.1) (3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from torchmetrics==0.10.3->dinov2==0.0.1) (23.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from torchmetrics==0.10.3->dinov2==0.0.1) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision==0.15.0->dinov2==0.0.1) (8.4.0)
# Collecting torch==2.0.0
#   Downloading https://download.pytorch.org/whl/cu117/torch-2.0.0%2Bcu117-cp39-cp39-linux_x86_64.whl (1843.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 573.4 kB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision==0.15.0->dinov2==0.0.1) (2.27.1)
# Collecting pyre-extensions==0.0.23
#   Downloading pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->dinov2==0.0.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->dinov2==0.0.1) (16.0.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from cuml-cu11->dinov2==0.0.1) (0.12.2)
# Collecting dask-cudf-cu11==23.4.*
#   Downloading https://pypi.nvidia.com/dask-cudf-cu11/dask_cudf_cu11-23.4.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 7.1 MB/s eta 0:00:00
# Collecting raft-dask-cu11==23.4.*
#   Downloading https://pypi.nvidia.com/raft-dask-cu11/raft_dask_cu11-23.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (215.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.1/215.1 MB 5.9 MB/s eta 0:00:00
# Collecting dask==2023.3.2
#   Downloading dask-2023.3.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.0 MB/s eta 0:00:00
# Collecting cudf-cu11==23.4.*
#   Downloading https://pypi.nvidia.com/cudf-cu11/cudf_cu11-23.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (496.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.7/496.7 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: cupy-cuda11x<12.0.0a0,>=9.5.0 in /usr/local/lib/python3.9/dist-packages (from cuml-cu11->dinov2==0.0.1) (11.0.0)
# Collecting dask-cuda==23.4.*
#   Downloading dask_cuda-23.4.0-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from cuml-cu11->dinov2==0.0.1) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from cuml-cu11->dinov2==0.0.1) (1.2.0)
# Collecting distributed==2023.3.2.1
#   Downloading distributed-2023.3.2.1-py3-none-any.whl (957 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 957.1/957.1 kB 71.1 MB/s eta 0:00:00
# Collecting treelite==3.2.0
#   Downloading treelite-3.2.0-py3-none-manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from cuml-cu11->dinov2==0.0.1) (0.56.4)
# Collecting treelite-runtime==3.2.0
#   Downloading treelite_runtime-3.2.0-py3-none-manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.2/198.2 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.9/dist-packages (from cudf-cu11==23.4.*->cuml-cu11->dinov2==0.0.1) (5.3.0)
# Collecting pyarrow==10.*
#   Downloading pyarrow-10.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 22.3 MB/s eta 0:00:00
# Collecting rmm-cu11==23.4.*
#   Downloading https://pypi.nvidia.com/rmm-cu11/rmm_cu11-23.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 90.9 MB/s eta 0:00:00
# Collecting nvtx>=0.2.1
#   Downloading nvtx-0.2.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.3/441.3 kB 42.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from cudf-cu11==23.4.*->cuml-cu11->dinov2==0.0.1) (2023.4.0)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.3 in /usr/local/lib/python3.9/dist-packages (from cudf-cu11==23.4.*->cuml-cu11->dinov2==0.0.1) (1.5.3)
# Collecting cuda-python<12.0,>=11.7.1
#   Downloading cuda_python-11.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 73.2 MB/s eta 0:00:00
# Collecting protobuf<4.22,>=4.21.6
#   Downloading protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 43.7 MB/s eta 0:00:00
# Collecting cubinlinker-cu11
#   Downloading https://pypi.nvidia.com/cubinlinker-cu11/cubinlinker_cu11-0.3.0.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 104.3 MB/s eta 0:00:00
# Collecting ptxcompiler-cu11
#   Downloading https://pypi.nvidia.com/ptxcompiler-cu11/ptxcompiler_cu11-0.7.0.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 107.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (6.4.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (1.4.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (2.2.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (0.12.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (8.1.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (6.0)
# Collecting pynvml<11.5,>=11.0.0
#   Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from dask-cuda==23.4.*->cuml-cu11->dinov2==0.0.1) (2.2.0)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (1.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (6.2)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (1.0.5)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (1.7.0)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (2.4.0)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from distributed==2023.3.2.1->cuml-cu11->dinov2==0.0.1) (1.26.15)
# Collecting pylibraft-cu11==23.4.*
#   Downloading https://pypi.nvidia.com/pylibraft-cu11/pylibraft_cu11-23.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 MB 2.7 MB/s eta 0:00:00
# Collecting ucx-py-cu11==0.31.*
#   Downloading https://pypi.nvidia.com/ucx-py-cu11/ucx_py_cu11-0.31.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 99.8 MB/s eta 0:00:00
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from fvcore->dinov2==0.0.1) (4.65.0)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.9/dist-packages (from fvcore->dinov2==0.0.1) (2.2.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from fvcore->dinov2==0.0.1) (0.8.10)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.9/dist-packages (from cupy-cuda11x<12.0.0a0,>=9.5.0->cuml-cu11->dinov2==0.0.1) (0.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch==2.0.0->dinov2==0.0.1) (2.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->cuml-cu11->dinov2==0.0.1) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->cuml-cu11->dinov2==0.0.1) (0.39.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.0->dinov2==0.0.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.0->dinov2==0.0.1) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.0->dinov2==0.0.1) (2.0.12)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn->cuml-cu11->dinov2==0.0.1) (3.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch==2.0.0->dinov2==0.0.1) (1.3.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from cuda-python<12.0,>=11.7.1->cudf-cu11==23.4.*->cuml-cu11->dinov2==0.0.1) (0.29.34)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.13.0->dask==2023.3.2->cuml-cu11->dinov2==0.0.1) (3.15.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11==23.4.*->cuml-cu11->dinov2==0.0.1) (2022.7.1)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from zict>=0.1.3->dask-cuda==23.4.*->cuml-cu11->dinov2==0.0.1) (1.0.1)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn->cuml-cu11->dinov2==0.0.1) (1.16.0)
# Building wheels for collected packages: dinov2, fvcore, iopath, antlr4-python3-runtime
#   Building wheel for dinov2 (pyproject.toml) ... done
#   Created wheel for dinov2: filename=dinov2-0.0.1-py3-none-any.whl size=90119 sha256=dec5a6bdce2868161b57dce30a723748cd95db918e91dedcb01c0ac8992edec5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vz0s5mh7/wheels/b1/a5/0c/ade4ca18d5b48dabcc55a025e5d10ffbf407a1fd6b3ed77beb
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61429 sha256=a301ba2eb1f6ead89151c53e04715b882587af76cdedf28b706107b422b33fb5
#   Stored in directory: /root/.cache/pip/wheels/83/42/02/66178d16e5c44dc26d309931834956baeda371956e86fbd876
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=10d3c5dcbb75a473bd0df374129f8dbef9f7ffdee677f1ca4ebc219a228a49f9
#   Stored in directory: /root/.cache/pip/wheels/c1/13/6d/441d8f2af76ee6d2a3e67eebb1d0c556fefcee0a8b32266a8e
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=166e46b940e37e1721c815a455f4b01ddbf3b719d135a5091e0bf5890064206d
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built dinov2 fvcore iopath antlr4-python3-runtime
# Installing collected packages: ptxcompiler-cu11, nvtx, cubinlinker-cu11, antlr4-python3-runtime, yacs, submitit, pynvml, pyarrow, protobuf, portalocker, omegaconf, mypy-extensions, cuda-python, ucx-py-cu11, typing-inspect, treelite-runtime, treelite, rmm-cu11, iopath, dask, pyre-extensions, pylibraft-cu11, fvcore, distributed, cudf-cu11, dask-cudf-cu11, dask-cuda, raft-dask-cu11, cuml-cu11, torch, xformers, torchvision, torchmetrics, dinov2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.12.1
#     Uninstalling dask-2022.12.1:
#       Successfully uninstalled dask-2022.12.1
#   Attempting uninstall: distributed
#     Found existing installation: distributed 2022.12.1
#     Uninstalling distributed-2022.12.1:
#       Successfully uninstalled distributed-2022.12.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 10.0.1 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 cubinlinker-cu11-0.3.0.post1 cuda-python-11.8.1 cudf-cu11-23.4.1 cuml-cu11-23.4.1 dask-2023.3.2 dask-cuda-23.4.0 dask-cudf-cu11-23.4.1 dinov2-0.0.1 distributed-2023.3.2.1 fvcore-0.1.5.post20221221 iopath-0.1.10 mypy-extensions-1.0.0 nvtx-0.2.5 omegaconf-2.3.0 portalocker-2.7.0 protobuf-4.21.12 ptxcompiler-cu11-0.7.0.post1 pyarrow-10.0.1 pylibraft-cu11-23.4.1 pynvml-11.4.1 pyre-extensions-0.0.23 raft-dask-cu11-23.4.1 rmm-cu11-23.4.1 submitit-1.4.5 torch-2.0.0+cu117 torchmetrics-0.10.3 torchvision-0.15.0+cu117 treelite-3.2.0 treelite-runtime-3.2.0 typing-inspect-0.8.0 ucx-py-cu11-0.31.1 xformers-0.0.18 yacs-0.1.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic[visualization]
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 4.7 MB/s eta 0:00:00
# WARNING: bertopic 0.14.1 does not provide the extra 'visualization'
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 59.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.2.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.5.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (4.65.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (5.13.1)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (0.29.34)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 90.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.0+cu117)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.15.0+cu117)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3580437 sha256=27a2ec0ada963fa884e04fbb4242a504f5645d93f6761f9647b6f12279c5397e
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=eef2641b9fde008464988b09e03c29219cd13e91e00998f26b3ab54873f69d0a
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=fdbf404fc5bd5354acd00a5c3de48ab1a5a1341a54e6cc93e1ed6e4512fdce2a
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=de6510f004ba18a5f25a688ad79c44ed6718e0bb3309538195f2accb70ff6810
#   Stored in directory: /root/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.4 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1 umap-learn-0.5.3

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
title = train['Book-Title'].drop_duplicates().to_list()

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !pip install stop-words
# Out:
# Requirement already satisfied: stop-words in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (2018.7.23)

# %%
from stop_words import get_stop_words
# 불용어 리스트
languages = [
   'Arabic',
   'Bulgarian',
   'Catalan',
   'Czech',
   'Danish',
   'Dutch',
   'English',
   'Finnish',
   'French',
   'German',
   'Hungarian',
   'Indonesian',
   'Italian',
   'Norwegian',
   'Polish',
   'Portuguese',
   'Romanian',
   'Russian',
   'Spanish',
   'Swedish',
   'Turkish',
   'Ukrainian'
]
my_stop_word_list = []
for i in languages:
    my_stop_word_list.append(get_stop_words(i.lower()))
my_stop_word_list = sum(my_stop_word_list, [])
my_stop_word_list = my_stop_word_list + ['paperbook', 'hardcover']

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
from cuml.cluster import HDBSCAN
from cuml.manifold import UMAP
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import KeyBERTInspired
from cuml.preprocessing import normalize

np.random.seed(113)
# 벡터화 모델
vectorizer_model = CountVectorizer(stop_words=my_stop_word_list, ngram_range=(1, 2), min_df=10)

# Create instances of GPU-accelerated UMAP and HDBSCAN (GPU사용 모델)
umap_model = UMAP(n_components=5, n_neighbors=300, min_dist=0.0, metric='cosine', random_state =113)
hdbscan_model = HDBSCAN(metric='euclidean', min_samples=10, gen_min_span_tree=True, prediction_data=True)
# 불용어 처리
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
# Create your representation model
representation_model = KeyBERTInspired(random_state = 113)

model = BERTopic(vectorizer_model=vectorizer_model,
                 ctfidf_model=ctfidf_model,
                 umap_model=umap_model, 
                 hdbscan_model=hdbscan_model,
                 representation_model=representation_model,
                 # 다국어를 위해 해당 임베딩 모델 사용
                 embedding_model="paraphrase-multilingual-MiniLM-L12-v2",
                 nr_topics="auto",
                 low_memory = True,
                 language="multilingual",
                 verbose = True,
                 top_n_words = 12,
                 min_topic_size = 500
                 )

model.fit(title)
topics, probs = model.transform(title)
# Out:
# Batches:   0%|          | 0/6808 [00:00<?, ?it/s]
# 2023-04-24 09:40:17,815 - BERTopic - Transformed documents to Embeddings
# 2023-04-24 09:40:46,082 - BERTopic - Reduced dimensionality
# 2023-04-24 09:41:32,785 - BERTopic - Clustered reduced embeddings
# 2023-04-24 09:41:49,542 - BERTopic - Reduced number of topics from 911 to 727
# Batches:   0%|          | 0/6808 [00:00<?, ?it/s]
# 2023-04-24 09:42:58,236 - BERTopic - Reduced dimensionality
# 2023-04-24 09:42:58,852 - BERTopic - Predicted clusters

# %%
model.get_topic_info()
# Out:
#      Topic   Count                                               Name
# 0       -1  145910  -1_cuentos_leaf books_book series_complete novels
# 1        0    3500          0_bride_wedding_harlequin intrigue_brides
# 2        1    2363                  1_testament_bible_jesus_christian
# 3        2    1707                  2_darkness_shadows_dark_moonlight
# 4        3    1612            3_parenting_parent guide_parent_parents
# ..     ...     ...                                                ...
# 722    721       5                  721_vintage international_thank__
# 723    722       5                             722_stories_book_life_
# 724    723       5                  723_wisdom_times_depression_guide
# 725    724       5                    724_soup_recipes_bowl_president
# 726    725       5                                       725_novel___
#
# [727 rows x 3 columns]

# %%
model.save("my_topics_model_usingGPU")

# %%
title = pd.DataFrame(title, columns = ['Book-Title'])

# %%
topic = pd.Series(topics, name = 'Topic_num')
topic
# Out:
# 0         -1
# 1         40
# 2          6
# 3         -1
# 4         -1
#           ..
# 217824    -1
# 217825    -1
# 217826    -1
# 217827    -1
# 217828    -1
# Name: Topic_num, Length: 217829, dtype: int64

# %%
title = pd.concat([title, topic], axis =1)
title
# Out:
#                                                Book-Title  Topic_num
# 0                                              Road Taken         -1
# 1                       Macbeth (New Penguin Shakespeare)         40
# 2                      Waverley (Penguin English Library)          6
# 3                                 Mother Earth Father Sky         -1
# 4                                       She Who Remembers         -1
# ...                                                   ...        ...
# 217824                                 Be Victorious (Be)         -1
# 217825     Prodigals and Those Who Love Them: Study Guide         -1
# 217826  A Transatlantic Love Affair: Letters to Nelson...         -1
# 217827  He's My Brother: Former Racial Foes Offer Stra...         -1
# 217828  Creme De Colorado Cookbook (Celebrating Twenty...         -1
#
# [217829 rows x 2 columns]

# %%
title_t = test['Book-Title'].drop_duplicates().to_list()

# %%
topics_t, probs_t = model.transform(title_t)
# Out:
# Batches:   0%|          | 0/1857 [00:00<?, ?it/s]
# 2023-04-24 09:43:24,271 - BERTopic - Reduced dimensionality
# 2023-04-24 09:43:24,458 - BERTopic - Predicted clusters

# %%
topic_t = pd.Series(topics_t, name = 'Topic_num')
title_t = pd.DataFrame(title_t, columns = ['Book-Title'])
title_t = pd.concat([title_t, topic_t], axis =1)
title_t
# Out:
#                                               Book-Title  Topic_num
# 0                     Birds of Prey: A Novel of Suspense         -1
# 1                                        Midnight Voices          2
# 2      Breaking Free : A Prescription for Personal an...         -1
# 3                                         Bitter Harvest         -1
# 4                                  Embraced by the Light          2
# ...                                                  ...        ...
# 59403     Changelings (Castlemere Mysteries (Paperback))         -1
# 59404                          MARKETING HIGH TECHNOLOGY         -1
# 59405   Sierra: Notes and Images from the Range of Light         -1
# 59406  From 60 Yards In : How to Master Golf's Short ...        155
# 59407        Avalanche Safety: For Skiers &amp; Climbers         -1
#
# [59408 rows x 2 columns]

# %%
# 나이 그룹화
labels = ['0-3','3-6','6-8','8-12','12-18','18-25','25-34','35-44','45-54','55-64','65-74','75+']
bins = [0, 3, 6, 8, 12, 18, 25, 34, 44, 54, 64, 74, 250]
train['Age_gb'] = pd.cut(train.Age, bins, labels = labels,include_lowest = True)

# %%
test['Age_gb'] = pd.cut(test.Age, bins, labels = labels,include_lowest = True)

# %%
from sklearn.preprocessing import OrdinalEncoder

FEATURE = ['User-ID', 'Book-Title','Book-Author','Publisher', 'City','State','Country', 'Topic_num','Age_gb']

train_lb = train.__deepcopy__() 
test_lb = test.__deepcopy__()
train_lb = pd.merge(train_lb, title, left_on = 'Book-Title', right_on = 'Book-Title', how = 'left')
test_lb = pd.merge(test_lb, title_t, left_on = 'Book-Title', right_on = 'Book-Title', how = 'left')

train_lb = train_lb.drop(columns = ['Book-ID', 'Location'])
test_lb = test_lb.drop(columns = ['Book-ID', 'Location'])

train_lb[FEATURE] = train_lb[FEATURE].astype(str) 
test_lb[FEATURE] = test_lb[FEATURE].astype(str)

for i in FEATURE:
    # train에는 없고, test에는 있는 원소는 -2 처리
    oe = OrdinalEncoder(handle_unknown='use_encoded_value',
                         unknown_value=-2)
    oe=oe.fit(train_lb[i].to_numpy().reshape(-1, 1))
    train_lb[i] = oe.transform(train_lb[i].to_numpy().reshape(-1, 1))
    test_lb[i] = oe.transform(test_lb[i].to_numpy().reshape(-1, 1))

# %%
X_train = train_lb.drop(columns = ['ID','Book-Rating'])
y_train = train_lb['Book-Rating']
x_test = test_lb.drop(columns = ['ID'])

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !pip install optuna
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 6.0 MB/s eta 0:00:0000:01
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.10.3-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 5.7 MB/s eta 0:00:00a 0:00:01
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from optuna) (23.1)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 7.2 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: tqdm in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna)
#   Downloading greenlet-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.7/613.7 kB 5.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./miniconda3/envs/rapids-23.04/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, greenlet, colorlog, cmaes, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.3 cmaes-0.9.1 colorlog-6.7.0 greenlet-2.0.2 optuna-3.1.1 sqlalchemy-2.0.10

# %%
import optuna
from optuna import Trial, visualization
from optuna.samplers import TPESampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor, Pool


X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# random sampler
sampler = TPESampler(seed=113)

# define function
def objective(trial):


    cbrm_param = {
        'l2_leaf_reg':trial.suggest_float("l2_leaf_reg",2,20),
        'max_bin': trial.suggest_int("max_bin", 200, 400),
        'learning_rate' : trial.suggest_loguniform('learning_rate', 0.001, 0.01),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15]),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 300),
        'iterations':trial.suggest_int("iterations", 1000, 25000),
        #'random_strength' :trial.suggest_int('random_strength', 0, 10),
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        #'min_child_samples': trial.suggest_int("min_child_samples", 5, 100),
        'eval_metric' : 'RMSE',
        'task_type': 'GPU',
        'random_state': 113,
        'use_best_model': True,
        'bootstrap_type' : 'Poisson',
        'early_stopping_rounds' : 100
    }

    FEATURE = ['User-ID', 'Book-Title','Book-Author','Publisher', 'City','State','Country', 'Topic_num','Age_gb']
    train_pool = Pool(data=X_train.astype('int'), label=y_train, cat_features=FEATURE)
    valid_pool = Pool(data=X_val.astype('int'), label=y_val, cat_features=FEATURE)

    # Generate model
    model_cbrm = CatBoostRegressor(**cbrm_param)
    model_cbrm = model_cbrm.fit(train_pool, eval_set=valid_pool, 
                           verbose=0, early_stopping_rounds=100)
                           
    MSE = mean_squared_error(y_val, model_cbrm.predict(X_val.astype('int')))
    RMSE = np.sqrt(MSE)
    return RMSE
optuna_cbrm = optuna.create_study(direction='minimize', sampler=sampler)
optuna_cbrm.optimize(objective, n_trials=1000, timeout = 36000)
# Out:
# [I 2023-04-24 10:05:52,626] A new study created in memory with name: no-name-8136ef15-cdae-4198-9935-af59eac02f35
# Warning: less than 75% gpu memory available for training. Free: 2985 Total: 8191.375
# [W 2023-04-24 10:05:56,990] Trial 0 failed with parameters: {'l2_leaf_reg': 17.335738869141586, 'max_bin': 214, 'learning_rate': 0.007851122663573896, 'max_depth': 11, 'min_data_in_leaf': 206, 'iterations': 17816, 'subsample': 0.8678165576938894} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/home/chunbae/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_1604/404059256.py", line 41, in objective
#     model_cbrm = model_cbrm.fit(train_pool, eval_set=valid_pool,
#   File "/home/chunbae/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py", line 5730, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#   File "/home/chunbae/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py", line 2355, in _fit
#     self._train(
#   File "/home/chunbae/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py", line 1759, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4623, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4672, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-04-24 10:05:56,991] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 48
#      46     return RMSE
#      47 optuna_cbrm = optuna.create_study(direction='minimize', sampler=sampler)
# ---> 48 optuna_cbrm.optimize(objective, n_trials=1000, timeout = 36000)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/study.py:425, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     321 def optimize(
#     322     self,
#     323     func: ObjectiveFuncType,
#    (...)
#     330     show_progress_bar: bool = False,
#     331 ) -> None:
#     332     """Optimize an objective function.
#     333
#     334     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     422             If nested invocation of this method occurs.
#     423     """
# --> 425     _optimize(
#     426         study=self,
#     427         func=func,
#     428         n_trials=n_trials,
#     429         timeout=timeout,
#     430         n_jobs=n_jobs,
#     431         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     432         callbacks=callbacks,
#     433         gc_after_trial=gc_after_trial,
#     434         show_progress_bar=show_progress_bar,
#     435     )
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[30], line 41, in objective(trial)
#      39 # Generate model
#      40 model_cbrm = CatBoostRegressor(**cbrm_param)
# ---> 41 model_cbrm = model_cbrm.fit(train_pool, eval_set=valid_pool,
#      42                        verbose=0, early_stopping_rounds=100)
#      44 MSE = mean_squared_error(y_val, model_cbrm.predict(X_val.astype('int')))
#      45 RMSE = np.sqrt(MSE)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:5730, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5727 if 'loss_function' in params:
#    5728     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5730 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5731                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5732                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5733                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:2355, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2351 allow_clear_pool = train_params["allow_clear_pool"]
#    2353 with log_fixup(log_cout, log_cerr), \
#    2354     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2355     self._train(
#    2356         train_pool,
#    2357         train_params["eval_sets"],
#    2358         params,
#    2359         allow_clear_pool,
#    2360         train_params["init_model"]
#    2361     )
#    2363 # Have property feature_importance possibly set
#    2364 loss = self._object._get_loss_function_name()
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:1759, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1758 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1759     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1760     self._set_trained_model_attributes()
#
# File _catboost.pyx:4623, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4672, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
cbrm_trial = optuna_cbrm.best_trial
cbrm_trial_params = cbrm_trial.params
print('Best Trial: score {},\nparams {}'.format(cbrm_trial.value, cbrm_trial_params))

cbrm_trial_params

# %%
from catboost import CatBoostRegressor 

model = CatBoostRegressor(random_seed = 113,
                          l2_leaf_reg = 0.003426034644149707,
                          max_bin = 358,
                          subsample = 0.9974697184313627,
                          learning_rate = 0.009464402227606937,
                          max_depth = 11,
                          min_data_in_leaf = 139,
                          eval_metric = 'RMSE',
                          iterations = 8694,
                          task_type='GPU',
                          bootstrap_type = 'Poisson',
                          early_stopping_rounds = 100,
                          verbose=500
                          )

# %%
from sklearn.model_selection import KFold, StratifiedKFold
skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=113)
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from catboost import CatBoostRegressor, Pool

y_valid_pred = 0*y_train
y_test_pred = 0

FEATURE = ['User-ID', 'Book-Title','Book-Author','Publisher', 'City','State','Country', 'Topic_num','Age_gb']

for i, (train_index, test_index) in enumerate(skfold.split(X_train, y_train)):    
    X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[test_index]

    train_pool = Pool(data=X_train_fold.astype('int'), label=y_train_fold, cat_features=FEATURE)
    valid_pool = Pool(data=X_valid_fold.astype('int'), label=y_valid_fold, cat_features=FEATURE)

    print( "\nFold ", i)
    
    fit_model = model.fit(train_pool, 
                          eval_set=valid_pool,
                          use_best_model=True
                          )
    print( "  N trees = ", model.tree_count_ )
        
    # Generate validation predictions for this fold
    pred = fit_model.predict(X_valid_fold.astype('int'))
    y_valid_pred.iloc[test_index] = pred
    
    # Predict value Clipping
    y_test_pred +=  np.clip(fit_model.predict(x_test[X_valid_fold.columns].astype('int')),0.0,10.0)
    
y_test_pred /= 5  # Average test set predictions
# Out:
# Fold  0
# Warning: less than 75% gpu memory available for training. Free: 2985 Total: 8191.375
# 0:	learn: 3.8400192	test: 3.8395278	best: 3.8395278 (0)	total: 312ms	remaining: 45m 10s
# 500:	learn: 3.3251183	test: 3.2887693	best: 3.2887693 (500)	total: 41s	remaining: 11m 10s
# 1000:	learn: 3.2821291	test: 3.2713992	best: 3.2713992 (1000)	total: 1m 23s	remaining: 10m 39s
# 1500:	learn: 3.2494858	test: 3.2643513	best: 3.2643513 (1500)	total: 2m 5s	remaining: 10m 2s
# 2000:	learn: 3.2175736	test: 3.2601714	best: 3.2601714 (2000)	total: 2m 48s	remaining: 9m 25s
# 2500:	learn: 3.1891317	test: 3.2575198	best: 3.2575198 (2500)	total: 3m 32s	remaining: 8m 45s
# 3000:	learn: 3.1616158	test: 3.2557227	best: 3.2557153 (2999)	total: 4m 15s	remaining: 8m 4s
# 3500:	learn: 3.1346436	test: 3.2544934	best: 3.2544934 (3500)	total: 4m 58s	remaining: 7m 22s
# 4000:	learn: 3.1091796	test: 3.2536243	best: 3.2536220 (3996)	total: 5m 41s	remaining: 6m 40s
# 4500:	learn: 3.0843273	test: 3.2528146	best: 3.2528022 (4488)	total: 6m 25s	remaining: 5m 58s
# 5000:	learn: 3.0600045	test: 3.2523378	best: 3.2523378 (5000)	total: 7m 8s	remaining: 5m 16s
# 5500:	learn: 3.0353753	test: 3.2519421	best: 3.2519380 (5498)	total: 7m 52s	remaining: 4m 34s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 22
#      18 valid_pool = Pool(data=X_valid_fold.astype('int'), label=y_valid_fold, cat_features=FEATURE)
#      20 print( "\nFold ", i)
# ---> 22 fit_model = model.fit(train_pool,
#      23                       eval_set=valid_pool,
#      24                       use_best_model=True
#      25                       )
#      26 print( "  N trees = ", model.tree_count_ )
#      28 # Generate validation predictions for this fold
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:5730, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5727 if 'loss_function' in params:
#    5728     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5730 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5731                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5732                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5733                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:2355, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2351 allow_clear_pool = train_params["allow_clear_pool"]
#    2353 with log_fixup(log_cout, log_cerr), \
#    2354     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2355     self._train(
#    2356         train_pool,
#    2357         train_params["eval_sets"],
#    2358         params,
#    2359         allow_clear_pool,
#    2360         train_params["init_model"]
#    2361     )
#    2363 # Have property feature_importance possibly set
#    2364 loss = self._object._get_loss_function_name()
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/catboost/core.py:1759, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1758 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1759     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1760     self._set_trained_model_attributes()
#
# File _catboost.pyx:4623, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4672, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
sub = pd.DataFrame()
sub['ID'] = test['ID']
sub['Book-Rating'] = y_test_pred
sub

# %%
import seaborn as sns
sns.histplot(sub['Book-Rating'])

# %%
sub.to_csv('submit_cat+bertopic_optuna3.csv', index=False,encoding="utf-8-sig")
